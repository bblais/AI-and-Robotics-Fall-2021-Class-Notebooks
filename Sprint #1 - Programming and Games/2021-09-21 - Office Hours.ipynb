# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from mplturtle import *

# %%
def back(length):
    right(180)
    forward(length)
    left(180)

# %%
reset()
for i in range(91):
    forward(50)
    back(50)
    left(10)
    
pencolor('red')
for i in range(91):
    forward(50)
    back(50)
    left(1)

# %%
def square(size):
    for i in range(4):
        forward(size)
        right(90)

# %%
reset()
for i in range(45):
    
    penup()
    forward(50)
    
    pendown()
    square(10)
    penup()
    back(50)
    
    left(2)
